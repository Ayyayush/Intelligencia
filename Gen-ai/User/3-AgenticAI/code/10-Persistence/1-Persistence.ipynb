# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq                 # correct Groq LLM import
from dotenv import load_dotenv 
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:05.386616+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, tasks=(PregelTask(id='41655137-e41c-3a4f-d63e-b52b23bc1d38', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:04.404906+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, tasks=(PregelTask(id='d52f11d8-b384-ae9c-08c8-7913813d6093', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:04.344794+00:00', parent_config=None, tasks=(PregelTask(id='b818f90d-62c7-1550-73a1-f53acb8ce4d0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."',
#  'explanation': 'The joke is a play on words. The phrase "feeling a little twisted" has a double meaning here. \n\nIn one sense, "twisted" can refer to a mental state of being emotionally disturbed or having psychological issues, which is why someone might go to therapy. This is the context in which the phrase is typically used.\n\nHowever, in the context of the joke, "twisted" also refers to the physical state of spaghetti, which is a type of pasta that is long and curved, often twisted into various shapes. This is a clever pun, as the joke is making a connection between the emotional state of being "twisted" and the physical state of the spaghetti being twisted.\n\nThe joke relies on this wordplay to create a humorous connection between the setup (the spaghetti going to therapy) and the punchline (feeling a little "twisted"). It\'s a lighthearted and clever play on words that creates a sense of surprise and delight.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:05.386616+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, tasks=(PregelTask(id='41655137-e41c-3a4f-d63e-b52b23bc1d38', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:04.404906+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, tasks=(PregelTask(id='d52f11d8-b384-ae9c-08c8-7913813d6093', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:04.344794+00:00', parent_config=None, tasks=(PregelTask(id='b818f90d-62c7-1550-73a1-f53acb8ce4d0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# ### Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
workflow.invoke(
    {"topic": "pizza"},   # input dena hi dena hai
    {
        "configurable": {
            "thread_id": "1",
            "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"
        }
    }
)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9d54-625a-8002-ebfa94acd41f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:08.096282+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-97d5-6a22-8001-b1f949555e63'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-97d5-6a22-8001-b1f949555e63'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:07.520168+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-94ae-67b3-8000-515177b9e3c0'}}, tasks=(PregelTask(id='8d87e705-f8e2-2c22-8b5b-d8f03a65c39c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-94ae-67b3-8000-515177b9e3c0'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:07.189559+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-949d-68e6-bfff-e4709f4f38f5'}}, tasks=(PregelTask(id='efab1562-7199-bab4-468d-8c71dbb1cb90', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-949d-68e6-bfff-e4709f4f38f5'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:07.182632+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='48b4879c-cf4f-45a3-bb48-d82e4881301a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:05.386616+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, tasks=(PregelTask(id='41655137-e41c-3a4f-d63e-b52b23bc1d38', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:04.404906+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, tasks=(PregelTask(id='d52f11d8-b384-ae9c-08c8-7913813d6093', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:04.344794+00:00', parent_config=None, tasks=(PregelTask(id='b818f90d-62c7-1550-73a1-f53acb8ce4d0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# #### Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f137557-9e30-668b-8000-0f2e0acfa2ad'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9e30-668b-8000-0f2e0acfa2ad'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:08.186495+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='53c4314b-0696-6e98-6089-ca22f3aa8764', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9d54-625a-8002-ebfa94acd41f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:08.096282+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-97d5-6a22-8001-b1f949555e63'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-97d5-6a22-8001-b1f949555e63'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:07.520168+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-94ae-67b3-8000-515177b9e3c0'}}, tasks=(PregelTask(id='8d87e705-f8e2-2c22-8b5b-d8f03a65c39c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-94ae-67b3-8000-515177b9e3c0'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:07.189559+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-949d-68e6-bfff-e4709f4f38f5'}}, tasks=(PregelTask(id='efab1562-7199-bab4-468d-8c71dbb1cb90', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-949d-68e6-bfff-e4709f4f38f5'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:07.182632+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='48b4879c-cf4f-45a3-bb48-d82e4881301a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:05.386616+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, tasks=(PregelTask(id='41655137-e41c-3a4f-d63e-b52b23bc1d38', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:04.404906+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, tasks=(PregelTask(id='d52f11d8-b384-ae9c-08c8-7913813d6093', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:04.344794+00:00', parent_config=None, tasks=(PregelTask(id='b818f90d-62c7-1550-73a1-f53acb8ce4d0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.invoke(
    {"topic": "pizza"},   # 🔥 MUST
    {
        "configurable": {
            "thread_id": "1",
            "checkpoint_id": "1f06cc72-ca16-6359-8001-7eea05e07dd2"
        }
    }
)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-a9a0-6bf4-8002-fc026c811d33'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:09.385946+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-a3af-61ed-8001-ea5e8812dcf1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-a3af-61ed-8001-ea5e8812dcf1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:08.762696+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9ee9-6230-8000-13afe11a3631'}}, tasks=(PregelTask(id='04ef0151-b355-ae02-8210-a43dba585d27', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9ee9-6230-8000-13afe11a3631'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:08.262160+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9ee1-6c91-bfff-0db8ee24a8de'}}, tasks=(PregelTask(id='fe1b3e66-0df9-4994-41c2-8200489bdb6c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9ee1-6c91-bfff-0db8ee24a8de'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:08.259164+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc72-ca16-6359-8001-7eea05e07dd2'}}, tasks=(PregelTask(id='4cd666bf-a86d-1f3d-ba03-bad9a97f49b8', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9e30-668b-8000-0f2e0acfa2ad'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:08.186495+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='53c4314b-0696-6e98-6089-ca22f3aa8764', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-9d54-625a-8002-ebfa94acd41f'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:08.096282+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-97d5-6a22-8001-b1f949555e63'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-97d5-6a22-8001-b1f949555e63'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:07.520168+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-94ae-67b3-8000-515177b9e3c0'}}, tasks=(PregelTask(id='8d87e705-f8e2-2c22-8b5b-d8f03a65c39c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-94ae-67b3-8000-515177b9e3c0'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:07.189559+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-949d-68e6-bfff-e4709f4f38f5'}}, tasks=(PregelTask(id='efab1562-7199-bab4-468d-8c71dbb1cb90', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-949d-68e6-bfff-e4709f4f38f5'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:07.182632+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='48b4879c-cf4f-45a3-bb48-d82e4881301a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-883e-6179-8002-7d010611c539'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-13T16:26:05.885241+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-837c-6bf3-8001-44121acf6d2d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-13T16:26:05.386616+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, tasks=(PregelTask(id='41655137-e41c-3a4f-d63e-b52b23bc1d38', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-7a20-6048-8000-37dc8c5cfb52'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-13T16:26:04.404906+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, tasks=(PregelTask(id='d52f11d8-b384-ae9c-08c8-7913813d6093', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f137557-798d-63c7-bfff-618026ec27c2'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-13T16:26:04.344794+00:00', parent_config=None, tasks=(PregelTask(id='b818f90d-62c7-1550-73a1-f53acb8ce4d0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# ### Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
